# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# %%
data = pd.read_csv('https://raw.githubusercontent.com/amankharwal/Website-data/master/dailyActivity_merged.csv')
pd.set_option('display.max_rows',950)
pd.set_option('display.max_columns',16)

data
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    4/12/2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# 5    1503960366    4/17/2016        9705       6.480000         6.480000
# 6    1503960366    4/18/2016       13019       8.590000         8.590000
# 7    1503960366    4/19/2016       15506       9.880000         9.880000
# 8    1503960366    4/20/2016       10544       6.680000         6.680000
# 9    1503960366    4/21/2016        9819       6.340000         6.340000
# 10   1503960366    4/22/2016       12764       8.130000         8.130000
# 11   1503960366    4/23/2016       14371       9.040000         9.040000
# ...

# %%
# !pip install plotly

# %%
data.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  9.400000e+02    940.000000     940.000000       940.000000
# mean   4.855407e+09   7637.910638       5.489702         5.475351
# std    2.424805e+09   5087.150742       3.924606         3.907276
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.320127e+09   3789.750000       2.620000         2.620000
# 50%    4.445115e+09   7405.500000       5.245000         5.245000
# 75%    6.962181e+09  10727.000000       7.712500         7.710000
# max    8.877689e+09  36019.000000      28.030001        28.030001
#
#        LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# count                940.000000          940.000000                940.000000
# mean                   0.108171            1.502681                  0.567543
# std                    0.619897            2.658941                  0.883580
# ...

# %%
data.isnull().sum()
# Out:
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 15 columns):
# Id                          940 non-null int64
# ActivityDate                940 non-null object
# TotalSteps                  940 non-null int64
# TotalDistance               940 non-null float64
# TrackerDistance             940 non-null float64
# LoggedActivitiesDistance    940 non-null float64
# VeryActiveDistance          940 non-null float64
# ModeratelyActiveDistance    940 non-null float64
# LightActiveDistance         940 non-null float64
# SedentaryActiveDistance     940 non-null float64
# VeryActiveMinutes           940 non-null int64
# FairlyActiveMinutes         940 non-null int64
# LightlyActiveMinutes        940 non-null int64
# SedentaryMinutes            940 non-null int64
# Calories                    940 non-null int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 110.2+ KB

# %%
# Changing datatype of ActivityDate
data['ActivityDate'] = pd.to_datetime(data['ActivityDate'],format = "%m/&d/&y")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 15 columns):
# Id                          940 non-null int64
# ActivityDate                940 non-null datetime64[ns]
# TotalSteps                  940 non-null int64
# TotalDistance               940 non-null float64
# TrackerDistance             940 non-null float64
# LoggedActivitiesDistance    940 non-null float64
# VeryActiveDistance          940 non-null float64
# ModeratelyActiveDistance    940 non-null float64
# LightActiveDistance         940 non-null float64
# SedentaryActiveDistance     940 non-null float64
# VeryActiveMinutes           940 non-null int64
# FairlyActiveMinutes         940 non-null int64
# LightlyActiveMinutes        940 non-null int64
# SedentaryMinutes            940 non-null int64
# Calories                    940 non-null int64
# dtypes: datetime64[ns](1), float64(7), int64(7)
# memory usage: 110.2 KB

# %%
#combine all columns contain minutes as total minutes before moving forward:
data["TotalMinutes"] = data["VeryActiveMinutes"]+data["FairlyActiveMinutes"]+data["LightlyActiveMinutes"]+data["SedentaryMinutes"]

data["TotalMinutes"].sample(5)
# Out:
# 361    1440
# 634    1440
# 194     902
# 40     1440
# 341     997
# Name: TotalMinutes, dtype: int64

# %%
#relationship between calories burned and the total steps walked in a day

Calories = data['Calories'].head(20)
TotalSteps = data['TotalSteps'].head(20)
sns.barplot( x= Calories ,y = TotalSteps ,palette = 'winter')
plt.xticks(rotation='vertical')
plt.title("Relationship between Calories & Total Steps",fontsize = 14)
# Out:
# Text(0.5, 1.0, 'Relationship between Calories & Total Steps')

# %%
figure = px.scatter(data_frame = data.head(10), x="Calories",
                    y="TotalSteps", size="VeryActiveMinutes", 
                    trendline="ols", 
                    title="Relationship between Calories & Total Steps")
figure.show()
# Out:
# <div>                            <div id="e661352a-cf3d-4a54-8bd7-38c422b3bfd1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e661352a-cf3d-4a54-8bd7-38c422b3bfd1")) {                    Plotly.newPlot(                        "e661352a-cf3d-4a54-8bd7-38c422b3bfd1",                        [{"hovertemplate":"Calories=%{x}\u003cbr\u003eTotalSteps=%{y}\u003cbr\u003eVeryActiveMinutes=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","size":[25,21,30,29,36,38,42,50,28,19],"sizemode":"area","sizeref":0.125,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[1985,1797,1776,1745,1863,1728,1921,2035,1786,1775],"xaxis":"x","y":[13162,10735,10460,9762,12669,9705,13019,15506
# ...

# %%
label = ["Very Active Minutes", "Fairly Active Minutes", 
         "Lightly Active Minutes", "Inactive Minutes"]
counts = data[["VeryActiveMinutes", "FairlyActiveMinutes", 
               "LightlyActiveMinutes", "SedentaryMinutes"]].mean()
colors = ['gold','lightgreen', "pink", "blue"]

fig = go.Figure(data=[go.Pie(labels=label, values=counts)])
fig.update_layout(title_text='Total Active Minutes')
fig.update_traces(hoverinfo='label+percent', textinfo='value', textfont_size=30,
                  marker=dict(colors=colors, line=dict(color='black', width=3)))
fig.show()
# Out:
# <div>                            <div id="594c0db8-179f-4aa2-a38e-7b55727b7b4f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("594c0db8-179f-4aa2-a38e-7b55727b7b4f")) {                    Plotly.newPlot(                        "594c0db8-179f-4aa2-a38e-7b55727b7b4f",                        [{"labels":["Very Active Minutes","Fairly Active Minutes","Lightly Active Minutes","Inactive Minutes"],"values":[21.164893617021278,13.564893617021276,192.8127659574468,991.2106382978724],"type":"pie","textfont":{"size":30},"marker":{"line":{"color":"black","width":3},"colors":["gold","lightgreen","pink","blue"]},"hoverinfo":"label+percent","textinfo":"value"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorba
# ...

# %%
data["Day"]=data["ActivityDate"].dt.day_name()
data["Day"].head(10)
# Out:
# 0      Tuesday
# 1    Wednesday
# 2     Thursday
# 3       Friday
# 4     Saturday
# 5       Sunday
# 6       Monday
# 7      Tuesday
# 8    Wednesday
# 9     Thursday
# Name: Day, dtype: object

# %%
ig = go.Figure()
fig.add_trace(go.Bar(
    x=data["Day"],
    y=data["VeryActiveMinutes"],
    name='Very Active',
    marker_color='purple'
))
fig.add_trace(go.Bar(
    x=data["Day"],
    y=data["FairlyActiveMinutes"],
    name='Fairly Active',
    marker_color='green'
))
fig.add_trace(go.Bar(
    x=data["Day"],
    y=data["LightlyActiveMinutes"],
    name='Lightly Active',
    marker_color='pink'
))
fig.update_layout(barmode='group', xaxis_tickangle=-45)
fig.show()
# Out:
# <div>                            <div id="0d345b6b-9680-4b24-8538-e02cb48b3dc6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0d345b6b-9680-4b24-8538-e02cb48b3dc6")) {                    Plotly.newPlot(                        "0d345b6b-9680-4b24-8538-e02cb48b3dc6",                        [{"labels":["Very Active Minutes","Fairly Active Minutes","Lightly Active Minutes","Inactive Minutes"],"values":[21.164893617021278,13.564893617021276,192.8127659574468,991.2106382978724],"type":"pie","textfont":{"size":30},"marker":{"line":{"color":"black","width":3},"colors":["gold","lightgreen","pink","blue"]},"hoverinfo":"label+percent","textinfo":"value"},{"marker":{"color":"purple"},"name":"Very Active","x":["Tuesday","Wednesday","Thursday","Friday","Saturda
# ...

# %%
day = data["Day"].value_counts()
label = day.index
counts = data["SedentaryMinutes"]
colors = ['gold','lightgreen', "pink", "blue", "skyblue", "cyan", "orange"]

fig = go.Figure(data=[go.Pie(labels=label, values=counts)])
fig.update_layout(title_text='Inactive Minutes Daily')
fig.update_traces(hoverinfo='label+percent', textinfo='value', textfont_size=30,
                  marker=dict(colors=colors, line=dict(color='black', width=3)))
fig.show()
# Out:
# <div>                            <div id="cd0a3cf1-3256-424e-8876-df8ac116134d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cd0a3cf1-3256-424e-8876-df8ac116134d")) {                    Plotly.newPlot(                        "cd0a3cf1-3256-424e-8876-df8ac116134d",                        [{"labels":["Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday"],"values":[728,776,1218,726,773,539,1149,775,818,838,1217,732,709,814,833,1108,782,815,712,730,798,816,1179,857,754,833,574,835,746,669,1440,1294,1292,1204,1344,1264,1276,1214,1299,1289,1254,1241,1213,1221,1238,1300,1233,1320,1290,1182,1020,1261,1344,1322,1323,1338,1258,1288,1349,1301,1328,890,1131,1259,1125,1263,1135,1212,1271,1099,1315,1402,1354,1265,1351,1337,1165,1322,1157,1193,
# ...
